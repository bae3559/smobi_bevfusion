# %%
from truckscenes import TruckScenes

trucksc = TruckScenes('v1.0-mini', '/home/bevfusion/data/man-truckscenes', True)
# 예: 노트북에서 보고 있던 sample_token을 알고 있다고 치고
my_scene = trucksc.scene[0]

first_sample_token = my_scene['first_sample_token']

trucksc.render_sample(first_sample_token)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 from truckscenes import TruckScenes
# ----> 3 trucksc = TruckScenes('v1.0-mini', '/data/man-truckscenes', True)
#       4 # 예: 노트북에서 보고 있던 sample_token을 알고 있다고 치고
#       5 my_scene = trucksc.scene[0]
#
# File ~/.local/lib/python3.10/site-packages/truckscenes/truckscenes.py:55, in TruckScenes.__init__(self, version, dataroot, verbose)
#      50 self.verbose = verbose
#      51 self.table_names = ['attribute', 'calibrated_sensor', 'category', 'ego_motion_cabin',
#      52                     'ego_motion_chassis', 'ego_pose', 'instance', 'sample',
#      53                     'sample_annotation', 'sample_data', 'scene', 'sensor', 'visibility']
# ---> 55 assert osp.exists(self.table_root), \
#      56     f'Database version not found: {self.table_root}'
#      58 start_time = time.time()
# ...

# %%
# !pip install truckscenes-devkit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [truckscenes-devkit]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip
